# %%
from statistics import mean
import numpy as np
import matplotlib.pyplot as plt

# %%
xs = np.array(sorted(np.random.randint(0,50,25)), dtype=np.float64)
ys = np.array(sorted(np.random.randint(0,50,25)), dtype=np.float64)
plt.figure(figsize=[10,8])
plt.scatter(xs,ys);

# %%
def best_fit_slope(a,b):
    m = (((mean(a)*mean(b)) - (mean(a*b))) / 
    ((mean(a)*mean(a))-mean(a*a)))
    c = mean(b) - m*mean(a)
    return(m,c)

# %%
m,c = best_fit_slope(xs,ys)
print(m,c)
# Out:
# 0.9634121820558115 -0.7916397374581621

# %%
reg_line = [((m*x) + c) for x in xs]
print(reg_line)
plt.scatter(xs,ys)
plt.plot(reg_line)
plt.show()
# Out:
# [1.1351846266534609, 2.0985968087092726, 5.9522455369325185, 6.91565771898833, 7.879069901044142, 10.769306447211576, 11.732718629267387, 18.476603903658066, 21.366840449825503, 22.330252631881315, 24.257076995992936, 26.18390136010456, 28.11072572421618, 29.074137906271993, 29.074137906271993, 30.037550088327805, 30.037550088327805, 31.000962270383617, 41.598496272997544, 41.598496272997544, 42.561908455053356, 44.48873281916498, 45.45214500122079, 45.45214500122079, 46.4155571832766]

# %%
xss = np.array([1,2,3,4,5,6],dtype=np.float64)
yss = np.array([5,4,6,5,6,7],dtype=np.float64)
m,c = best_fit_slope(xss,yss)
reg_line = [(m*x + c) for x in xss]
plt.scatter(xss,yss)
plt.plot(reg_line)
plt.show()

# %%
xss = np.array([1,2,3,4,5,6],dtype=np.float64)
yss = np.array([5,4,6,5,6,7],dtype=np.float64)
print("stats mean of x" + str(mean(xss)))
print("numpy mean of x" + str(np.mean(xss)))
print("stats mean of y" + str(mean(yss)))
print("numpy mean of y" + str(np.mean(yss)))
# Out:
# stats mean of x3.5
# numpy mean of x3.5
# stats mean of y5.5
# numpy mean of y5.5

# %%
xss = np.array(sorted(np.random.randint(0,50,25)), dtype=np.float64)
yss = np.array(sorted(np.random.randint(0,50,25)), dtype=np.float64)
print("stats mean of x" + str(mean(xss)))
print("numpy mean of x" + str(np.mean(xss)))
print("stats mean of y" + str(mean(yss)))
print("numpy mean of y" + str(np.mean(yss)))
# Out:
# stats mean of x24.48
# numpy mean of x24.48
# stats mean of y22.52
# numpy mean of y22.52
